# %%
import multiprocessing.dummy as multiprocessing
from game import new_battle
from os import mkdir
import config
import sqlite3

rooms_now = []
rooms_now.append(make_new_room)
def make_new_room():
    global g 
    make_p(g)
    mkdir(config.way + "/rooms/" + str(g))
    s
    g+=1
def make_p(n):
    doit = multiprocessing.Pool()

    doit.apply(new_battle, [n])

# %%
import multiprocessing.dummy as multiprocessing
import time

def a():
    time.sleep(2)
    return 'a'
def b():
    time.sleep(2)
    return 'b'
def c():
    time.sleep(1)
    print(1)
    return 'c'

p = multiprocessing.Pool()

results = p.map(lambda f: f(),[a,b,c])
print(results)
p.close()
p.join()
p
# Out:
# 1
# ['a', 'b', 'c']

# %%
make_new_room()
# Out:
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 99 - check
# O4FARNPS 100 - check
# 84R0WUVS 100 - check
# V3X4E4KX 99 - check
# CSTR56Q2 100 - check
# 737TJG6A 100 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 99 - check
# O4FARNPS 100 - check
# 84R0WUVS 100 - check
# V3X4E4KX 99 - check
# CSTR56Q2 100 - check
# 737TJG6A 99 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 99 - check
# O4FARNPS 99 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 100 - check
# 737TJG6A 98 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 99 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 98 - check
# CSTR56Q2 100 - check
# 737TJG6A 98 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 98 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 98 - check
# CSTR56Q2 100 - check
# 737TJG6A 98 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 98 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 98 - check
# CSTR56Q2 100 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 98 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 97 - check
# CSTR56Q2 100 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 98 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 97 - check
# CSTR56Q2 100 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 97 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 97 - check
# CSTR56Q2 100 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 97 - check
# O4FARNPS 99 - check
# 84R0WUVS 99 - check
# V3X4E4KX 97 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 97 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 96 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 97 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 96 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 96 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 96 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 96 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 96 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 96 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 95 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 96 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 95 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 95 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 95 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 95 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 95 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 95 - check
# O4FARNPS 99 - check
# 84R0WUVS 98 - check
# V3X4E4KX 94 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 95 - check
# O4FARNPS 98 - check
# 84R0WUVS 98 - check
# V3X4E4KX 94 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 94 - check
# O4FARNPS 98 - check
# 84R0WUVS 98 - check
# V3X4E4KX 94 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 94 - check
# O4FARNPS 98 - check
# 84R0WUVS 98 - check
# V3X4E4KX 94 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 94 - check
# O4FARNPS 98 - check
# 84R0WUVS 98 - check
# V3X4E4KX 93 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 94 - check
# O4FARNPS 97 - check
# 84R0WUVS 98 - check
# V3X4E4KX 93 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 99 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 93 - check
# O4FARNPS 97 - check
# 84R0WUVS 98 - check
# V3X4E4KX 93 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 98 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 93 - check
# O4FARNPS 97 - check
# 84R0WUVS 98 - check
# V3X4E4KX 93 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 98 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 93 - check
# O4FARNPS 97 - check
# 84R0WUVS 98 - check
# V3X4E4KX 92 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 98 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 93 - check
# O4FARNPS 96 - check
# 84R0WUVS 98 - check
# V3X4E4KX 92 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 98 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 92 - check
# O4FARNPS 96 - check
# 84R0WUVS 98 - check
# V3X4E4KX 92 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 98 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 92 - check
# O4FARNPS 96 - check
# 84R0WUVS 98 - check
# V3X4E4KX 92 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 97 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 92 - check
# O4FARNPS 96 - check
# 84R0WUVS 98 - check
# V3X4E4KX 91 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 97 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 92 - check
# O4FARNPS 95 - check
# 84R0WUVS 98 - check
# V3X4E4KX 91 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 97 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 91 - check
# O4FARNPS 95 - check
# 84R0WUVS 98 - check
# V3X4E4KX 91 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 97 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 91 - check
# O4FARNPS 95 - check
# 84R0WUVS 98 - check
# V3X4E4KX 91 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 96 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 91 - check
# O4FARNPS 95 - check
# 84R0WUVS 98 - check
# V3X4E4KX 90 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 96 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 91 - check
# O4FARNPS 94 - check
# 84R0WUVS 98 - check
# V3X4E4KX 90 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 96 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 90 - check
# O4FARNPS 94 - check
# 84R0WUVS 98 - check
# V3X4E4KX 90 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 95 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 90 - check
# O4FARNPS 94 - check
# 84R0WUVS 98 - check
# V3X4E4KX 90 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 95 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 90 - check
# O4FARNPS 94 - check
# 84R0WUVS 98 - check
# V3X4E4KX 89 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 95 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 90 - check
# O4FARNPS 93 - check
# 84R0WUVS 98 - check
# V3X4E4KX 89 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 95 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 89 - check
# O4FARNPS 93 - check
# 84R0WUVS 98 - check
# V3X4E4KX 89 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 95 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 89 - check
# O4FARNPS 93 - check
# 84R0WUVS 98 - check
# V3X4E4KX 89 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 94 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 89 - check
# O4FARNPS 93 - check
# 84R0WUVS 98 - check
# V3X4E4KX 88 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 94 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 89 - check
# O4FARNPS 92 - check
# 84R0WUVS 98 - check
# V3X4E4KX 88 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 88 - check
# O4FARNPS 92 - check
# 84R0WUVS 98 - check
# V3X4E4KX 88 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 88 - check
# O4FARNPS 92 - check
# 84R0WUVS 98 - check
# V3X4E4KX 88 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 88 - check
# O4FARNPS 92 - check
# 84R0WUVS 98 - check
# V3X4E4KX 87 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 88 - check
# O4FARNPS 91 - check
# 84R0WUVS 98 - check
# V3X4E4KX 87 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 87 - check
# O4FARNPS 91 - check
# 84R0WUVS 98 - check
# V3X4E4KX 87 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 87 - check
# O4FARNPS 91 - check
# 84R0WUVS 98 - check
# V3X4E4KX 87 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 87 - check
# O4FARNPS 91 - check
# 84R0WUVS 98 - check
# V3X4E4KX 86 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 87 - check
# O4FARNPS 90 - check
# 84R0WUVS 98 - check
# V3X4E4KX 86 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 99 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 86 - check
# O4FARNPS 90 - check
# 84R0WUVS 98 - check
# V3X4E4KX 86 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 86 - check
# O4FARNPS 90 - check
# 84R0WUVS 98 - check
# V3X4E4KX 86 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 86 - check
# O4FARNPS 90 - check
# 84R0WUVS 98 - check
# V3X4E4KX 84 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 86 - check
# O4FARNPS 89 - check
# 84R0WUVS 98 - check
# V3X4E4KX 84 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 85 - check
# O4FARNPS 89 - check
# 84R0WUVS 98 - check
# V3X4E4KX 84 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 93 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 85 - check
# O4FARNPS 89 - check
# 84R0WUVS 98 - check
# V3X4E4KX 84 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 98 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 85 - check
# O4FARNPS 89 - check
# 84R0WUVS 98 - check
# V3X4E4KX 83 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 85 - check
# O4FARNPS 88 - check
# 84R0WUVS 97 - check
# V3X4E4KX 83 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 84 - check
# O4FARNPS 88 - check
# 84R0WUVS 97 - check
# V3X4E4KX 83 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 84 - check
# O4FARNPS 88 - check
# 84R0WUVS 97 - check
# V3X4E4KX 83 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 84 - check
# O4FARNPS 88 - check
# 84R0WUVS 97 - check
# V3X4E4KX 82 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 84 - check
# O4FARNPS 87 - check
# 84R0WUVS 97 - check
# V3X4E4KX 82 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 92 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 83 - check
# O4FARNPS 87 - check
# 84R0WUVS 97 - check
# V3X4E4KX 82 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 83 - check
# O4FARNPS 87 - check
# 84R0WUVS 97 - check
# V3X4E4KX 82 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 83 - check
# O4FARNPS 87 - check
# 84R0WUVS 97 - check
# V3X4E4KX 81 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 83 - check
# O4FARNPS 86 - check
# 84R0WUVS 97 - check
# V3X4E4KX 81 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 82 - check
# O4FARNPS 86 - check
# 84R0WUVS 97 - check
# V3X4E4KX 81 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 82 - check
# O4FARNPS 86 - check
# 84R0WUVS 97 - check
# V3X4E4KX 81 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 91 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 82 - check
# O4FARNPS 86 - check
# 84R0WUVS 97 - check
# V3X4E4KX 80 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 82 - check
# O4FARNPS 85 - check
# 84R0WUVS 97 - check
# V3X4E4KX 80 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 81 - check
# O4FARNPS 85 - check
# 84R0WUVS 97 - check
# V3X4E4KX 80 - check
# CSTR56Q2 100 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 81 - check
# O4FARNPS 85 - check
# 84R0WUVS 97 - check
# V3X4E4KX 80 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 81 - check
# O4FARNPS 85 - check
# 84R0WUVS 97 - check
# V3X4E4KX 79 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 81 - check
# O4FARNPS 84 - check
# 84R0WUVS 97 - check
# V3X4E4KX 79 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 80 - check
# O4FARNPS 84 - check
# 84R0WUVS 97 - check
# V3X4E4KX 79 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 80 - check
# O4FARNPS 84 - check
# 84R0WUVS 97 - check
# V3X4E4KX 79 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 80 - check
# O4FARNPS 84 - check
# 84R0WUVS 97 - check
# V3X4E4KX 78 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 97 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 80 - check
# O4FARNPS 83 - check
# 84R0WUVS 97 - check
# V3X4E4KX 78 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 96 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 79 - check
# O4FARNPS 83 - check
# 84R0WUVS 97 - check
# V3X4E4KX 78 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 96 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 79 - check
# O4FARNPS 83 - check
# 84R0WUVS 97 - check
# V3X4E4KX 78 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 96 - check
# KOFMUX42 90 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 79 - check
# O4FARNPS 83 - check
# 84R0WUVS 96 - check
# V3X4E4KX 77 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 96 - check
# KOFMUX42 89 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 79 - check
# O4FARNPS 82 - check
# 84R0WUVS 96 - check
# V3X4E4KX 77 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 94 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 78 - check
# O4FARNPS 82 - check
# 84R0WUVS 95 - check
# V3X4E4KX 77 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 93 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 78 - check
# O4FARNPS 82 - check
# 84R0WUVS 95 - check
# V3X4E4KX 77 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 93 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 78 - check
# O4FARNPS 82 - check
# 84R0WUVS 95 - check
# V3X4E4KX 76 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 93 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 78 - check
# O4FARNPS 81 - check
# 84R0WUVS 95 - check
# V3X4E4KX 76 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 92 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 77 - check
# O4FARNPS 81 - check
# 84R0WUVS 95 - check
# V3X4E4KX 76 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 92 - check
# KOFMUX42 88 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 77 - check
# O4FARNPS 81 - check
# 84R0WUVS 95 - check
# V3X4E4KX 76 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 91 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 77 - check
# O4FARNPS 81 - check
# 84R0WUVS 95 - check
# V3X4E4KX 75 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 91 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 77 - check
# O4FARNPS 80 - check
# 84R0WUVS 95 - check
# V3X4E4KX 75 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 90 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 76 - check
# O4FARNPS 80 - check
# 84R0WUVS 95 - check
# V3X4E4KX 75 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 90 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 76 - check
# O4FARNPS 80 - check
# 84R0WUVS 95 - check
# V3X4E4KX 75 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 90 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 76 - check
# O4FARNPS 80 - check
# 84R0WUVS 95 - check
# V3X4E4KX 74 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 90 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 76 - check
# O4FARNPS 79 - check
# 84R0WUVS 95 - check
# V3X4E4KX 74 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 75 - check
# O4FARNPS 79 - check
# 84R0WUVS 95 - check
# V3X4E4KX 74 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 75 - check
# O4FARNPS 79 - check
# 84R0WUVS 95 - check
# V3X4E4KX 74 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 75 - check
# O4FARNPS 79 - check
# 84R0WUVS 95 - check
# V3X4E4KX 73 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 75 - check
# O4FARNPS 78 - check
# 84R0WUVS 95 - check
# V3X4E4KX 73 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 74 - check
# O4FARNPS 78 - check
# 84R0WUVS 95 - check
# V3X4E4KX 73 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 87 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 74 - check
# O4FARNPS 78 - check
# 84R0WUVS 95 - check
# V3X4E4KX 73 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 86 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 74 - check
# O4FARNPS 78 - check
# 84R0WUVS 95 - check
# V3X4E4KX 72 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 88 - check
# KOFMUX42 86 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 74 - check
# O4FARNPS 77 - check
# 84R0WUVS 95 - check
# V3X4E4KX 72 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 86 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 73 - check
# O4FARNPS 77 - check
# 84R0WUVS 95 - check
# V3X4E4KX 72 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 85 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 73 - check
# O4FARNPS 77 - check
# 84R0WUVS 95 - check
# V3X4E4KX 72 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 85 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 73 - check
# O4FARNPS 77 - check
# 84R0WUVS 95 - check
# V3X4E4KX 71 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 85 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 73 - check
# O4FARNPS 76 - check
# 84R0WUVS 95 - check
# V3X4E4KX 71 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 84 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 72 - check
# O4FARNPS 76 - check
# 84R0WUVS 95 - check
# V3X4E4KX 71 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 72 - check
# O4FARNPS 76 - check
# 84R0WUVS 95 - check
# V3X4E4KX 71 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 72 - check
# O4FARNPS 76 - check
# 84R0WUVS 95 - check
# V3X4E4KX 70 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 72 - check
# O4FARNPS 75 - check
# 84R0WUVS 95 - check
# V3X4E4KX 70 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 75 - check
# 84R0WUVS 95 - check
# V3X4E4KX 70 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 75 - check
# 84R0WUVS 95 - check
# V3X4E4KX 70 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 75 - check
# 84R0WUVS 95 - check
# V3X4E4KX 69 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 87 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 74 - check
# 84R0WUVS 95 - check
# V3X4E4KX 69 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 86 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 74 - check
# 84R0WUVS 95 - check
# V3X4E4KX 69 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 86 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 74 - check
# 84R0WUVS 95 - check
# V3X4E4KX 69 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 85 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 74 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 85 - check
# KOFMUX42 83 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 73 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 84 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 73 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 84 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 73 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 83 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 73 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 83 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 72 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 82 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 72 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 82 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 72 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 81 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 72 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 81 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 71 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 80 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 71 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 80 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 71 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 79 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 71 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 79 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 70 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 70 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 70 - check
# 84R0WUVS 95 - check
# V3X4E4KX 68 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 70 - check
# 84R0WUVS 95 - check
# V3X4E4KX 67 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 71 - check
# O4FARNPS 69 - check
# 84R0WUVS 95 - check
# V3X4E4KX 67 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 70 - check
# O4FARNPS 69 - check
# 84R0WUVS 95 - check
# V3X4E4KX 67 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 70 - check
# O4FARNPS 69 - check
# 84R0WUVS 95 - check
# V3X4E4KX 67 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 70 - check
# O4FARNPS 69 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 82 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 70 - check
# O4FARNPS 68 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 68 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 78 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 68 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 77 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 68 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 96 - check
# DA7DGNSE 77 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 67 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 95 - check
# DA7DGNSE 76 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 67 - check
# 84R0WUVS 95 - check
# V3X4E4KX 66 - check
# CSTR56Q2 99 - check
# 737TJG6A 95 - check
# DA7DGNSE 76 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 67 - check
# 84R0WUVS 95 - check
# V3X4E4KX 65 - check
# CSTR56Q2 98 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 67 - check
# 84R0WUVS 95 - check
# V3X4E4KX 64 - check
# CSTR56Q2 98 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 69 - check
# O4FARNPS 66 - check
# 84R0WUVS 95 - check
# V3X4E4KX 63 - check
# CSTR56Q2 98 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 68 - check
# O4FARNPS 66 - check
# 84R0WUVS 95 - check
# V3X4E4KX 63 - check
# CSTR56Q2 98 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 68 - check
# O4FARNPS 66 - check
# 84R0WUVS 95 - check
# V3X4E4KX 63 - check
# CSTR56Q2 97 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 68 - check
# O4FARNPS 65 - check
# 84R0WUVS 95 - check
# V3X4E4KX 62 - check
# CSTR56Q2 97 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 68 - check
# O4FARNPS 64 - check
# 84R0WUVS 95 - check
# V3X4E4KX 62 - check
# CSTR56Q2 97 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 81 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 64 - check
# 84R0WUVS 95 - check
# V3X4E4KX 62 - check
# CSTR56Q2 97 - check
# 737TJG6A 95 - check
# DA7DGNSE 75 - check
# KOFMUX42 80 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 64 - check
# 84R0WUVS 95 - check
# V3X4E4KX 62 - check
# CSTR56Q2 96 - check
# 737TJG6A 95 - check
# DA7DGNSE 74 - check
# KOFMUX42 79 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 63 - check
# 84R0WUVS 95 - check
# V3X4E4KX 61 - check
# CSTR56Q2 96 - check
# 737TJG6A 95 - check
# DA7DGNSE 74 - check
# KOFMUX42 79 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 62 - check
# 84R0WUVS 95 - check
# V3X4E4KX 61 - check
# CSTR56Q2 96 - check
# 737TJG6A 95 - check
# DA7DGNSE 73 - check
# KOFMUX42 79 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 62 - check
# 84R0WUVS 95 - check
# V3X4E4KX 61 - check
# CSTR56Q2 96 - check
# 737TJG6A 95 - check
# DA7DGNSE 73 - check
# KOFMUX42 79 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 62 - check
# 84R0WUVS 95 - check
# V3X4E4KX 61 - check
# CSTR56Q2 95 - check
# 737TJG6A 95 - check
# DA7DGNSE 72 - check
# KOFMUX42 78 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 62 - check
# 84R0WUVS 95 - check
# V3X4E4KX 61 - check
# CSTR56Q2 95 - check
# 737TJG6A 95 - check
# DA7DGNSE 72 - check
# KOFMUX42 78 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 61 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 95 - check
# 737TJG6A 95 - check
# DA7DGNSE 71 - check
# KOFMUX42 78 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 61 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 95 - check
# 737TJG6A 95 - check
# DA7DGNSE 71 - check
# KOFMUX42 78 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 61 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 94 - check
# 737TJG6A 95 - check
# DA7DGNSE 70 - check
# KOFMUX42 78 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 61 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 94 - check
# 737TJG6A 95 - check
# DA7DGNSE 70 - check
# KOFMUX42 77 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 60 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 94 - check
# 737TJG6A 95 - check
# DA7DGNSE 69 - check
# KOFMUX42 77 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 60 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 94 - check
# 737TJG6A 95 - check
# DA7DGNSE 69 - check
# KOFMUX42 77 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 60 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 68 - check
# KOFMUX42 76 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 60 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 68 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 59 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 67 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 58 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 67 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 58 - check
# 84R0WUVS 95 - check
# V3X4E4KX 60 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 67 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 58 - check
# 84R0WUVS 95 - check
# V3X4E4KX 59 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 67 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 57 - check
# 84R0WUVS 95 - check
# V3X4E4KX 59 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 66 - check
# KOFMUX42 75 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 57 - check
# 84R0WUVS 95 - check
# V3X4E4KX 59 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 66 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 57 - check
# 84R0WUVS 95 - check
# V3X4E4KX 59 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 66 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 57 - check
# 84R0WUVS 95 - check
# V3X4E4KX 58 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 66 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 56 - check
# 84R0WUVS 95 - check
# V3X4E4KX 58 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 64 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 56 - check
# 84R0WUVS 95 - check
# V3X4E4KX 58 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 64 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 56 - check
# 84R0WUVS 95 - check
# V3X4E4KX 58 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 64 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 56 - check
# 84R0WUVS 95 - check
# V3X4E4KX 57 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 64 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 55 - check
# 84R0WUVS 95 - check
# V3X4E4KX 56 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 62 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 55 - check
# 84R0WUVS 95 - check
# V3X4E4KX 56 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 62 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 55 - check
# 84R0WUVS 95 - check
# V3X4E4KX 56 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 62 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 55 - check
# 84R0WUVS 95 - check
# V3X4E4KX 55 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 62 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 54 - check
# 84R0WUVS 95 - check
# V3X4E4KX 54 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 54 - check
# 84R0WUVS 95 - check
# V3X4E4KX 54 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 54 - check
# 84R0WUVS 95 - check
# V3X4E4KX 54 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 54 - check
# 84R0WUVS 95 - check
# V3X4E4KX 53 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 53 - check
# 84R0WUVS 95 - check
# V3X4E4KX 53 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 74 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 53 - check
# 84R0WUVS 95 - check
# V3X4E4KX 53 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 73 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 53 - check
# 84R0WUVS 95 - check
# V3X4E4KX 53 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 72 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 52 - check
# 84R0WUVS 95 - check
# V3X4E4KX 52 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 71 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 51 - check
# 84R0WUVS 95 - check
# V3X4E4KX 52 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 51 - check
# 84R0WUVS 95 - check
# V3X4E4KX 52 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 51 - check
# 84R0WUVS 95 - check
# V3X4E4KX 52 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 51 - check
# 84R0WUVS 95 - check
# V3X4E4KX 51 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 50 - check
# 84R0WUVS 95 - check
# V3X4E4KX 51 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 50 - check
# 84R0WUVS 95 - check
# V3X4E4KX 51 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 50 - check
# 84R0WUVS 95 - check
# V3X4E4KX 51 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 50 - check
# 84R0WUVS 95 - check
# V3X4E4KX 50 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 49 - check
# 84R0WUVS 95 - check
# V3X4E4KX 50 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 70 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 49 - check
# 84R0WUVS 95 - check
# V3X4E4KX 50 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 49 - check
# 84R0WUVS 95 - check
# V3X4E4KX 50 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 48 - check
# 84R0WUVS 95 - check
# V3X4E4KX 49 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 48 - check
# 84R0WUVS 95 - check
# V3X4E4KX 49 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 48 - check
# 84R0WUVS 95 - check
# V3X4E4KX 49 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 48 - check
# 84R0WUVS 95 - check
# V3X4E4KX 49 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 47 - check
# 84R0WUVS 95 - check
# V3X4E4KX 48 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 47 - check
# 84R0WUVS 95 - check
# V3X4E4KX 48 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 47 - check
# 84R0WUVS 95 - check
# V3X4E4KX 48 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 47 - check
# 84R0WUVS 95 - check
# V3X4E4KX 48 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 46 - check
# 84R0WUVS 95 - check
# V3X4E4KX 47 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 46 - check
# 84R0WUVS 95 - check
# V3X4E4KX 47 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 46 - check
# 84R0WUVS 95 - check
# V3X4E4KX 47 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 46 - check
# 84R0WUVS 95 - check
# V3X4E4KX 47 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 45 - check
# 84R0WUVS 95 - check
# V3X4E4KX 46 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 45 - check
# 84R0WUVS 95 - check
# V3X4E4KX 46 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 45 - check
# 84R0WUVS 95 - check
# V3X4E4KX 46 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 45 - check
# 84R0WUVS 95 - check
# V3X4E4KX 46 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 44 - check
# 84R0WUVS 95 - check
# V3X4E4KX 45 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 44 - check
# 84R0WUVS 95 - check
# V3X4E4KX 45 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 44 - check
# 84R0WUVS 95 - check
# V3X4E4KX 45 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 44 - check
# 84R0WUVS 95 - check
# V3X4E4KX 45 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 42 - check
# 84R0WUVS 95 - check
# V3X4E4KX 44 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 42 - check
# 84R0WUVS 95 - check
# V3X4E4KX 43 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 41 - check
# 84R0WUVS 95 - check
# V3X4E4KX 43 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 40 - check
# 84R0WUVS 95 - check
# V3X4E4KX 42 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 39 - check
# 84R0WUVS 95 - check
# V3X4E4KX 41 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 39 - check
# 84R0WUVS 95 - check
# V3X4E4KX 41 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# DA7DGNSE 60 - check
# KOFMUX42 69 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 67 - check
# O4FARNPS 38 - check
# 84R0WUVS 95 - check
# V3X4E4KX 41 - check
# CSTR56Q2 93 - check
# 737TJG6A 95 - check
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-6956c3167db7> in <module>()
# ----> 1 make_new_room()
#
# <ipython-input-27-36d3b820712c> in make_new_room()
#       8 def make_new_room():
#       9     global g
# ---> 10     make_p(g)
#      11     mkdir(config.way + "/rooms/" + str(g))
#      12     g+=1
#
# <ipython-input-27-36d3b820712c> in make_p(n)
#      14     doit = multiprocessing.Pool()
#      15
# ---> 16     doit.apply(new_battle, [n])
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in apply(self, func, args, kwds)
#     251         '''
#     252         assert self._state == RUN
# --> 253         return self.apply_async(func, args, kwds).get()
#     254
#     255     def map(self, func, iterable, chunksize=None):
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     606             return self._value
#     607         else:
# --> 608             raise self._value
#     609
#     610     def _set(self, i, obj):
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception:
#
# /home/hi_melnikov/Hakaton/game_module/game.py in new_battle(numer)
#     231                     y_now = coords[player]["y"]
#     232                     x_now = coords[player]["x"]
# --> 233                     mainMap[x_now][y_now] = player
#     234                     healthMap[x_now][y_now] = health[player]
#     235                     c.execute("UPDATE game SET y = " + str(coords[player]["y"]) + " WHERE key = ?", [player])
#
# IndexError: list index out of range

# %%
g = 1

# %%
import multiprocessing.dummy as multiprocessing
import time

def a():
    time.sleep(2)
    return 'a'
def b():
    time.sleep(2)
    return 'b'
def c():
    time.sleep(1)
    return 'c'

p = multiprocessing.Pool()

p.apply(new_battle)
p.close()
p.join()
# Out:
# {'width': '20', 'height': '12', 'mode': 'sandbox', 'max_health': '100', 'game_state': 'running', 'game_stop': '1', 'stop_ticks': '400'}
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 100 - check
# O4FARNPS 99 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 100 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 96 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 98 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 100 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 96 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 97 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 100 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 100 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 96 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 97 - check
# 737TJG6A 97 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 99 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 96 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 97 - check
# 737TJG6A 96 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 99 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 97 - check
# 737TJG6A 96 - check
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-89a890f56879> in <module>()
#      14 p = multiprocessing.Pool()
#      15
# ---> 16 p.apply(new_battle)
#      17 p.close()
#      18 p.join()
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in apply(self, func, args, kwds)
#     251         '''
#     252         assert self._state == RUN
# --> 253         return self.apply_async(func, args, kwds).get()
#     254
#     255     def map(self, func, iterable, chunksize=None):
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /home/hi_melnikov/.anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 99 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 96 - check
# 737TJG6A 95 - check
# DA7DGNSE 100 - check
# KOFMUX42 100 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 100 - check
# O4FARNPS 98 - check
# 84R0WUVS 100 - check
# V3X4E4KX 100 - check
# CSTR56Q2 99 - check
# 737TJG6A 100 - check
# DA7DGNSE 82 - check
# KOFMUX42 98 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 96 - check
# 737TJG6A 94 - check

# %%
import multiprocessing.dummy as multiprocessing
import time

def a():
    time.sleep(2)
    return 'a'
def b():
    time.sleep(2)
    return 'b'
def c():
    time.sleep(1)
    return 'c'

p = multiprocessing.Pool()

results = p.map(lambda f: f(),[a,b,c])
print(results)
p.close()
p.
# Out:
# ['a', 'b', 'c']

# %%
a = 5
# Out:
# DA7DGNSE 81 - check
# KOFMUX42 97 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 95 - check
# 737TJG6A 92 - check
# DA7DGNSE 96 - check
# KOFMUX42 100 - check
# 2QUSKL9O 98 - check
# ILU0XNCR 97 - check
# O4FARNPS 96 - check
# 84R0WUVS 97 - check
# V3X4E4KX 96 - check
# CSTR56Q2 93 - check
# 737TJG6A 98 - check
# DA7DGNSE 81 - check
# KOFMUX42 97 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 95 - check
# 737TJG6A 92 - check
# DA7DGNSE 96 - check
# KOFMUX42 100 - check
# 2QUSKL9O 98 - check
# ILU0XNCR 97 - check
# O4FARNPS 96 - check
# 84R0WUVS 97 - check
# V3X4E4KX 96 - check
# CSTR56Q2 93 - check
# 737TJG6A 97 - check
# DA7DGNSE 81 - check
# KOFMUX42 97 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 95 - check
# 737TJG6A 91 - check
# DA7DGNSE 96 - check
# KOFMUX42 99 - check
# 2QUSKL9O 98 - check
# ILU0XNCR 97 - check
# O4FARNPS 96 - check
# 84R0WUVS 97 - check
# V3X4E4KX 96 - check
# CSTR56Q2 93 - check
# 737TJG6A 96 - check
# DA7DGNSE 81 - check
# KOFMUX42 97 - check
# 2QUSKL9O 99 - check
# ILU0XNCR 95 - check
# O4FARNPS 93 - check
# 84R0WUVS 100 - check
# V3X4E4KX 98 - check
# CSTR56Q2 95 - check
# 737TJG6A 91 - check
